# %%
import pandas as pd
alunosDIC = {'Nome':['Ricardo', 'Pedro', 'Roberto', 'Carlos'],
          'Nota':[4, 7, 5.5, 9],
          'Aprovado':['Não', 'Sim','Não', 'Sim']}

# %%
alunosDF = pd.DataFrame(alunosDIC)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 alunosDF = pd.DataFrame(alunosDIC)
#
# NameError: name 'pd' is not defined

# %%
print(alunosDF)
# Out:
#       Nome  Nota Aprovado
# 0  Ricardo   4.0      Não
# 1    Pedro   7.0      Sim
# 2  Roberto   5.5      Não
# 3   Carlos   9.0      Sim

# %%
alunosDF['Nome']
# Out:
# 0    Ricardo
# 1      Pedro
# 2    Roberto
# 3     Carlos
# Name: Nome, dtype: str

# %%
alunosDF.loc[0:2]
# Out:
#       Nome  Nota Aprovado
# 0  Ricardo   4.0      Não
# 1    Pedro   7.0      Sim
# 2  Roberto   5.5      Não

# %%
alunosDF.loc[alunosDF['Nota']>=7]
# Out:
#      Nome  Nota Aprovado
# 1   Pedro   7.0      Sim
# 3  Carlos   9.0      Sim
