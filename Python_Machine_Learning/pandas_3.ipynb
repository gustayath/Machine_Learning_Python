# %%
import pandas as pd
alunosDIC = {'Nome':['Ricardo', 'Pedro', 'Roberto', 'Carlos'],
          'Nota':[4, 7, 5.5, 9],
          'Aprovado':['Não', 'Sim','Não', 'Sim']}

# %%
alunosDF = pd.DataFrame(alunosDIC)

# %%
print(alunosDF)
# Out:
#       Nome  Nota Aprovado
# 0  Ricardo   4.0      Não
# 1    Pedro   7.0      Sim
# 2  Roberto   5.5      Não
# 3   Carlos   9.0      Sim

# %%
alunosDF2 = alunosDF.loc[0:2]
print(alunosDF2)
# Out:
#       Nome  Nota Aprovado
# 0  Ricardo   4.0      Não
# 1    Pedro   7.0      Sim
# 2  Roberto   5.5      Não

# %%
alunosReprovados = alunosDF.loc[alunosDF['Nota']<= 6]
print(alunosReprovados)
# Out:
#       Nome  Nota Aprovado
# 0  Ricardo   4.0      Não
# 2  Roberto   5.5      Não
